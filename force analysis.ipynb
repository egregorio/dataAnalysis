# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv
import os
import glob

# %%
from mpl_toolkits import mplot3d

# %%
# name the files you want to import
P = '/Users/elizabeth/Desktop/parts';
#D = '09182021';
# put together the full filenames
files = glob.glob(P + "/parts.*")
print(files)
# Out:
# ['/Users/elizabeth/Desktop/parts/parts.000010', '/Users/elizabeth/Desktop/parts/parts.000017', '/Users/elizabeth/Desktop/parts/parts.000016', '/Users/elizabeth/Desktop/parts/parts.000011', '/Users/elizabeth/Desktop/parts/parts.000002', '/Users/elizabeth/Desktop/parts/parts.000005', '/Users/elizabeth/Desktop/parts/parts.000004', '/Users/elizabeth/Desktop/parts/parts.000003', '/Users/elizabeth/Desktop/parts/parts.000014', '/Users/elizabeth/Desktop/parts/parts.000013', '/Users/elizabeth/Desktop/parts/parts.000012', '/Users/elizabeth/Desktop/parts/parts.000015', '/Users/elizabeth/Desktop/parts/parts.000008', '/Users/elizabeth/Desktop/parts/parts.000006', '/Users/elizabeth/Desktop/parts/parts.000001', '/Users/elizabeth/Desktop/parts/parts.000000', '/Users/elizabeth/Desktop/parts/parts.000007', '/Users/elizabeth/Desktop/parts/parts.000009']

# %%
files0 = np.loadtxt(files[1],skiprows=2)
np.shape(files0)
files[1]
#files
# Out:
# '/Users/elizabeth/Desktop/parts/parts.000017'

# %%
variables = ['X', 'Y', 'Z', 'nx', 'ny', 'nz', 'p', 'fvx', 'fvy', 'fvz', 'wx', 'wy', 'wz']
len(variables)
# Out:
# 13

# %%
X = files0[:,0]
Y = files0[:,1]
Z = files0[:,2]
P = files0[:,6]

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(X, Z, Y, c=P, cmap='Greens');

# %%
files1 = np.loadtxt(files[7],skiprows=2)
print(files[7])

X = files1[:,0]
Y = files1[:,1]
Z = files1[:,2]
P = files1[:,6]

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(X, Z, Y, c=P, cmap='Greens');
# Out:
# /Users/elizabeth/Desktop/parts/parts.000003
